# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveenkumarSetty/CNN_Oxford-IIIT-Pet_data/blob/main/Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Classification on Oxford-IIIT Pet**

# %% [markdown]
# ## Importing Libraries

# %%
import os
import glob
import datetime
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf
from tensorflow.keras import Sequential
from keras.models import  model_from_json
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import L2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense,LeakyReLU, BatchNormalization, ReLU

# %%
tf.__version__
# Out:
# '2.7.0'

# %% [markdown]
# # Constants

# %% [markdown]
# Data

# %%
BASE_PATH = "/content/drive/MyDrive/SigTuple/images"
IMAGE_SIZE = (256, 256)
RANDOM_STATE = 7
TRAIN_SIZE, VAL_SIZE, TEST_SIZE = 0.8, 0.1, 0.1

# %% [markdown]
# Model

# %%
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.0001
PLOTS_DPI = 200

# %% [markdown]
# # Data loading

# %% [markdown]
# Reading Image Names

# %%
imageNames = [os.path.basename(file) for file in glob.glob(os.path.join(BASE_PATH, '*.jpg'))]
imageNames

print(f"\nTotal number of image files: {len(imageNames)}")
# Out:
# Total number of image files: 7390

# %% [markdown]
# Reading target label from filenames

# %%
labels = [' '.join(name.split('_')[:-1]) for name in imageNames ]

print(f"\nTotal number of unique labels: {len(np.unique(labels))}")
# Out:
# Total number of unique labels: 37

# %% [markdown]
# ### Lookup dictionary for Label Encoding

# %%
labelEncDict = {name : ind for ind, name in enumerate(np.unique(labels))}
for k, v in labelEncDict.items():
    print(f"{k:32} : {v}")
# Out:
# Abyssinian                       : 0
# Bengal                           : 1
# Birman                           : 2
# Bombay                           : 3
# British Shorthair                : 4
# Egyptian Mau                     : 5
# Maine Coon                       : 6
# Persian                          : 7
# Ragdoll                          : 8
# Russian Blue                     : 9
# Siamese                          : 10
# Sphynx                           : 11
# american bulldog                 : 12
# american pit bull terrier        : 13
# basset hound                     : 14
# beagle                           : 15
# boxer                            : 16
# chihuahua                        : 17
# english cocker spaniel           : 18
# english setter                   : 19
# german shorthaired               : 20
# great pyrenees                   : 21
# havanese                         : 22
# japanese chin                    : 23
# keeshond                         : 24
# leonberger                       : 25
# miniature pinscher               : 26
# newfoundland                     : 27
# pomeranian                       : 28
# pug                              : 29
# saint bernard                    : 30
# samoyed                          : 31
# scottish terrier                 : 32
# shiba inu                        : 33
# staffordshire bull terrier       : 34
# wheaten terrier                  : 35
# yorkshire terrier                : 36

# %% [markdown]
# ### Reverse lookup dictionary

# %%
labelDecDict = {ind: name for name, ind in labelEncDict.items()}
for k, v in labelDecDict.items():
    print(f"{k:3} : {v}")
# Out:
#   0 : Abyssinian
#   1 : Bengal
#   2 : Birman
#   3 : Bombay
#   4 : British Shorthair
#   5 : Egyptian Mau
#   6 : Maine Coon
#   7 : Persian
#   8 : Ragdoll
#   9 : Russian Blue
#  10 : Siamese
#  11 : Sphynx
#  12 : american bulldog
#  13 : american pit bull terrier
#  14 : basset hound
#  15 : beagle
#  16 : boxer
#  17 : chihuahua
#  18 : english cocker spaniel
#  19 : english setter
#  20 : german shorthaired
#  21 : great pyrenees
#  22 : havanese
#  23 : japanese chin
#  24 : keeshond
#  25 : leonberger
#  26 : miniature pinscher
#  27 : newfoundland
#  28 : pomeranian
#  29 : pug
#  30 : saint bernard
#  31 : samoyed
#  32 : scottish terrier
#  33 : shiba inu
#  34 : staffordshire bull terrier
#  35 : wheaten terrier
#  36 : yorkshire terrier

# %% [markdown]
# ## **Class distribution**

# %%
for i in labelEncDict.keys():
    print(f"{i:32} : {labels.count(i)}")
# Out:
# Abyssinian                       : 200
# Bengal                           : 200
# Birman                           : 200
# Bombay                           : 200
# British Shorthair                : 200
# Egyptian Mau                     : 200
# Maine Coon                       : 200
# Persian                          : 200
# Ragdoll                          : 200
# Russian Blue                     : 200
# Siamese                          : 200
# Sphynx                           : 200
# american bulldog                 : 200
# american pit bull terrier        : 200
# basset hound                     : 200
# beagle                           : 200
# boxer                            : 200
# chihuahua                        : 200
# english cocker spaniel           : 200
# english setter                   : 200
# german shorthaired               : 200
# great pyrenees                   : 200
# havanese                         : 200
# japanese chin                    : 200
# keeshond                         : 200
# leonberger                       : 200
# miniature pinscher               : 200
# newfoundland                     : 200
# pomeranian                       : 200
# pug                              : 200
# saint bernard                    : 200
# samoyed                          : 200
# scottish terrier                 : 199
# shiba inu                        : 200
# staffordshire bull terrier       : 191
# wheaten terrier                  : 200
# yorkshire terrier                : 200

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')


physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Load image data

# %%
imageData = []

for name in tqdm(imageNames, desc = 'Loading image data', unit = ' images'):
    img = load_img(os.path.join(BASE_PATH, name))
    img = tf.image.resize_with_pad(img_to_array(img, dtype = 'uint8'), *IMAGE_SIZE).numpy().astype('uint8')
    imageData.append(img)
    
imageData = np.array(imageData)
imageData.shape
# Out:
# Loading image data: 100%|██████████| 7390/7390 [02:13<00:00, 55.22 images/s]
# (7390, 256, 256, 3)

# %% [markdown]
# ### Encoding Target labels

# %%
labelsEncoded = list(map(lambda x : labelEncDict.get(x), labels))

for i, l in zip(imageNames[::1000], labelsEncoded[::1000]):
    print(f"{i:32}\t{labelDecDict[l]:32}\t{l}")
# Out:
# japanese_chin_127.jpg           	japanese chin                   	23
# pomeranian_180.jpg              	pomeranian                      	28
# saint_bernard_135.jpg           	saint bernard                   	30
# saint_bernard_23.jpg            	saint bernard                   	30
# Egyptian_Mau_215.jpg            	Egyptian Mau                    	5
# american_pit_bull_terrier_32.jpg	american pit bull terrier       	13
# yorkshire_terrier_88.jpg        	yorkshire terrier               	36
# chihuahua_165.jpg               	chihuahua                       	17

# %%
plt.subplots(nrows = 3, ncols = 3, figsize = (15, 15))

for i, imgIndex in enumerate(np.random.randint(0, len(imageNames), size = 9)):
  plt.subplot(3, 3, i + 1)
  plt.axis(False)
  plt.grid(False)
  plt.title(f'{imageNames[imgIndex]}\n{labels[imgIndex]}\n{labelsEncoded[imgIndex]}')
  plt.imshow(imageData[imgIndex])
plt.show()

# %%
imageData.max()
# Out:
# 255

# %% [markdown]
# ## **Train, Test and Validation preparation**

# %% [markdown]
# ### Split data and labels into 3 sets

# %%
X_tv, X_test, y_tv, y_test = train_test_split(
    imageData, 
    labelsEncoded, 
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE, 
    stratify = labelsEncoded
    )

X_train, X_val, y_train, y_val = train_test_split(
    X_tv, 
    y_tv, 
    test_size = VAL_SIZE, 
    random_state = RANDOM_STATE, 
    stratify = y_tv
    )

print(f'Training Data: {X_train.shape}')
print(f'Training Labels: {len(y_train)}')
print(f'\nValidation Data: {X_val.shape}')
print(f'Validation Labels: {len(y_val)}')
print(f'\nTesting Data: {X_test.shape}')
print(f'Testing Labels: {len(y_test)}')
# Out:
# Training Data: (5985, 256, 256, 3)
# Training Labels: 5985
#
# Validation Data: (666, 256, 256, 3)
# Validation Labels: 666
#
# Testing Data: (739, 256, 256, 3)
# Testing Labels: 739

# %% [markdown]
# ### Image Data Generator for training data using Image augmentation

# %%
train_gen = ImageDataGenerator(rescale = 1./255,
                               rotation_range = 30,
                               width_shift_range = 0.1,
                               height_shift_range = 0.1,
                               shear_range = 0.1,
                               zoom_range = 0.1,
                               horizontal_flip = True,
                               fill_mode = 'nearest')
train_data = train_gen.flow(x = X_train, y = y_train, batch_size = BATCH_SIZE, shuffle = True)
len(train_data)
# Out:
# 188

# %% [markdown]
# ### Image Data Generator for validation data

# %%
val_gen = ImageDataGenerator(rescale = 1./255)
val_data = val_gen.flow(x = X_val, y = y_val, batch_size = BATCH_SIZE, shuffle = True)
len(val_data)
# Out:
# 21

# %% [markdown]
# ### Image Data Generator for Test data

# %%
test_gen = ImageDataGenerator(rescale = 1./255)
test_data = test_gen.flow(x = X_test, y = y_test, batch_size = BATCH_SIZE)
len(test_data)
# Out:
# 24

# %% [markdown]
# ## Sample images from generators

# %%
def plot_generator_images(gen, suptitle, labelDecDict, print_pred = False, model = None, nrows = 3, ncols = 3, figsize = (12, 12)):
    gen_data = gen.next()
    
    plt.subplots(nrows = nrows, ncols = ncols, figsize = figsize)
    plt.suptitle(suptitle, fontsize = 20)
    plt.tight_layout(rect = [0, 0, 1, 0.96], h_pad = 2)
    
    if(print_pred and model):
        pred = np.argmax(model.predict(gen_data[0]), axis=1)

    for i in range(nrows * ncols):
        plt.subplot(nrows, ncols, i + 1)
        plt.axis(False)
        plt.grid(False)
        
        if(print_pred and pred.any()):
            plt.title(f"True: {labelDecDict[gen_data[1][i]]}\nPredicted: {labelDecDict[pred[i]]}")
        else:
            plt.title(labelDecDict[gen_data[1][i]])
        plt.imshow(gen_data[0][i])

# %% [markdown]
# Training Samples

# %%
plot_generator_images(train_data, "Training data", labelDecDict)

# %% [markdown]
# validation Samples

# %%
plot_generator_images(val_data, "Validation data", labelDecDict)

# %% [markdown]
# # **CNN Model**

# %% [markdown]
# ## **Model Creation**

# %%
model = Sequential([
    Conv2D(32, 5, padding = 'same', input_shape = (*IMAGE_SIZE, 3)),
    Conv2D(32, 5, padding = 'same', activation = LeakyReLU(alpha = 0.5)),
    MaxPooling2D(),
    Conv2D(32, 4, padding = 'same'),
    Conv2D(32, 4, padding = 'same', activation = LeakyReLU(alpha = 0.5)),
    MaxPooling2D(),

    Conv2D(64, 4, padding = 'same'),
    Conv2D(64, 4, padding = 'same', activation = LeakyReLU(alpha = 0.5)),
    MaxPooling2D(),
    BatchNormalization(),
    Conv2D(64, 3, padding = 'same'),
    Conv2D(64, 3, padding = 'same', activation = LeakyReLU(alpha = 0.5)),
    MaxPooling2D(),

    Conv2D(128, 3, padding = 'same'),
    Conv2D(128, 3, padding = 'same', activation = LeakyReLU(alpha = 0.5)),
    MaxPooling2D(),
    Conv2D(128, 2, padding = 'same'),
    Conv2D(128, 2, padding = 'same', activation = LeakyReLU(alpha = 0.5)),
    MaxPooling2D(),

    Conv2D(256, 2, padding = 'same'),
    Conv2D(256, 2, padding = 'same', activation = LeakyReLU(alpha = 0.5)),
    MaxPooling2D(),
    
    Flatten(),
    BatchNormalization(),
    Dropout(0.2),
    Dense(512, activation = 'sigmoid'),
    Dropout(0.2),
    Dense(256, activation = 'sigmoid'),
    Dropout(0.1),
    Dense(len(labelEncDict), activation = 'softmax')
])

model.compile(optimizer = Adam(LEARNING_RATE), 
              loss = 'sparse_categorical_crossentropy', 
              metrics = ['sparse_categorical_accuracy'])
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)      16416
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)      16416
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)        32832
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        65600
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        36928
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         65664
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         65664
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 4, 4, 256)         131328
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 256)         262400
#
#  max_pooling2d_6 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  batch_normalization_1 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 37)                9509
#
# =================================================================
# Total params: 1,649,669
# Trainable params: 1,647,493
# Non-trainable params: 2,176
# _________________________________________________________________

# %% [markdown]
# ### **Model Training**

# %%
history = model.fit(train_data, validation_data = val_data, epochs = EPOCHS, verbose = 1)
# Out:
# Epoch 1/50
# 188/188 [==============================] - 134s 632ms/step - loss: 3.6168 - sparse_categorical_accuracy: 0.0443 - val_loss: 3.6016 - val_sparse_categorical_accuracy: 0.0511
# Epoch 2/50
# 188/188 [==============================] - 115s 612ms/step - loss: 3.4936 - sparse_categorical_accuracy: 0.0648 - val_loss: 3.5337 - val_sparse_categorical_accuracy: 0.0616
# Epoch 3/50
# 188/188 [==============================] - 115s 610ms/step - loss: 3.3874 - sparse_categorical_accuracy: 0.0902 - val_loss: 3.3195 - val_sparse_categorical_accuracy: 0.1111
# Epoch 4/50
# 188/188 [==============================] - 116s 615ms/step - loss: 3.3085 - sparse_categorical_accuracy: 0.1046 - val_loss: 3.2662 - val_sparse_categorical_accuracy: 0.1231
# Epoch 5/50
# 188/188 [==============================] - 115s 613ms/step - loss: 3.2240 - sparse_categorical_accuracy: 0.1215 - val_loss: 3.1572 - val_sparse_categorical_accuracy: 0.1486
# Epoch 6/50
# 188/188 [==============================] - 115s 609ms/step - loss: 3.1390 - sparse_categorical_accuracy: 0.1348 - val_loss: 3.2447 - val_sparse_categorical_accuracy: 0.1261
# Epoch 7/50
# 188/188 [==============================] - 114s 603ms/step - loss: 3.0691 - sparse_categorical_accuracy: 0.1619 - val_loss: 3.0571 - val_sparse_categorical_accuracy: 0.1456
# Epoch 8/50
# 188/188 [==============================] - 113s 602ms/step - loss: 3.0089 - sparse_categorical_accuracy: 0.1733 - val_loss: 2.9288 - val_sparse_categorical_accuracy: 0.1982
# Epoch 9/50
# 188/188 [==============================] - 115s 612ms/step - loss: 2.9330 - sparse_categorical_accuracy: 0.1871 - val_loss: 2.8586 - val_sparse_categorical_accuracy: 0.2297
# Epoch 10/50
# 188/188 [==============================] - 113s 600ms/step - loss: 2.8826 - sparse_categorical_accuracy: 0.2023 - val_loss: 2.8710 - val_sparse_categorical_accuracy: 0.2057
# Epoch 11/50
# 188/188 [==============================] - 114s 603ms/step - loss: 2.8110 - sparse_categorical_accuracy: 0.2172 - val_loss: 2.8073 - val_sparse_categorical_accuracy: 0.1997
# Epoch 12/50
# 188/188 [==============================] - 114s 605ms/step - loss: 2.7408 - sparse_categorical_accuracy: 0.2386 - val_loss: 2.9670 - val_sparse_categorical_accuracy: 0.1847
# Epoch 13/50
# 188/188 [==============================] - 114s 604ms/step - loss: 2.6676 - sparse_categorical_accuracy: 0.2480 - val_loss: 2.7033 - val_sparse_categorical_accuracy: 0.2372
# Epoch 14/50
# 188/188 [==============================] - 114s 607ms/step - loss: 2.5928 - sparse_categorical_accuracy: 0.2760 - val_loss: 2.4809 - val_sparse_categorical_accuracy: 0.2838
# Epoch 15/50
# 188/188 [==============================] - 114s 603ms/step - loss: 2.5327 - sparse_categorical_accuracy: 0.2956 - val_loss: 2.5752 - val_sparse_categorical_accuracy: 0.2808
# Epoch 16/50
# 188/188 [==============================] - 113s 600ms/step - loss: 2.4483 - sparse_categorical_accuracy: 0.3106 - val_loss: 2.4221 - val_sparse_categorical_accuracy: 0.3288
# Epoch 17/50
# 188/188 [==============================] - 113s 599ms/step - loss: 2.3945 - sparse_categorical_accuracy: 0.3248 - val_loss: 2.5114 - val_sparse_categorical_accuracy: 0.2973
# Epoch 18/50
# 188/188 [==============================] - 113s 598ms/step - loss: 2.3212 - sparse_categorical_accuracy: 0.3460 - val_loss: 2.4934 - val_sparse_categorical_accuracy: 0.3168
# Epoch 19/50
# 188/188 [==============================] - 113s 602ms/step - loss: 2.2792 - sparse_categorical_accuracy: 0.3512 - val_loss: 2.3663 - val_sparse_categorical_accuracy: 0.3438
# Epoch 20/50
# 188/188 [==============================] - 117s 619ms/step - loss: 2.2039 - sparse_categorical_accuracy: 0.3721 - val_loss: 2.4477 - val_sparse_categorical_accuracy: 0.3213
# Epoch 21/50
# 188/188 [==============================] - 116s 613ms/step - loss: 2.1573 - sparse_categorical_accuracy: 0.3856 - val_loss: 2.2543 - val_sparse_categorical_accuracy: 0.3649
# Epoch 22/50
# 188/188 [==============================] - 116s 616ms/step - loss: 2.1088 - sparse_categorical_accuracy: 0.3890 - val_loss: 2.1191 - val_sparse_categorical_accuracy: 0.3739
# Epoch 23/50
# 188/188 [==============================] - 114s 607ms/step - loss: 2.0653 - sparse_categorical_accuracy: 0.3913 - val_loss: 2.1055 - val_sparse_categorical_accuracy: 0.3859
# Epoch 24/50
# 188/188 [==============================] - 119s 631ms/step - loss: 1.9885 - sparse_categorical_accuracy: 0.4217 - val_loss: 2.0040 - val_sparse_categorical_accuracy: 0.4129
# Epoch 25/50
# 188/188 [==============================] - 118s 624ms/step - loss: 1.9622 - sparse_categorical_accuracy: 0.4242 - val_loss: 1.9476 - val_sparse_categorical_accuracy: 0.4399
# Epoch 26/50
# 188/188 [==============================] - 117s 622ms/step - loss: 1.9203 - sparse_categorical_accuracy: 0.4332 - val_loss: 1.9774 - val_sparse_categorical_accuracy: 0.4159
# Epoch 27/50
# 188/188 [==============================] - 115s 613ms/step - loss: 1.8780 - sparse_categorical_accuracy: 0.4451 - val_loss: 1.9292 - val_sparse_categorical_accuracy: 0.4369
# Epoch 28/50
# 188/188 [==============================] - 114s 604ms/step - loss: 1.8142 - sparse_categorical_accuracy: 0.4632 - val_loss: 1.9076 - val_sparse_categorical_accuracy: 0.4324
# Epoch 29/50
# 188/188 [==============================] - 114s 607ms/step - loss: 1.8247 - sparse_categorical_accuracy: 0.4637 - val_loss: 1.9758 - val_sparse_categorical_accuracy: 0.4174
# Epoch 30/50
# 188/188 [==============================] - 113s 602ms/step - loss: 1.7638 - sparse_categorical_accuracy: 0.4767 - val_loss: 1.7623 - val_sparse_categorical_accuracy: 0.4820
# Epoch 31/50
# 188/188 [==============================] - 114s 608ms/step - loss: 1.7151 - sparse_categorical_accuracy: 0.4971 - val_loss: 1.7098 - val_sparse_categorical_accuracy: 0.4955
# Epoch 32/50
# 188/188 [==============================] - 113s 602ms/step - loss: 1.6821 - sparse_categorical_accuracy: 0.4996 - val_loss: 1.7446 - val_sparse_categorical_accuracy: 0.4880
# Epoch 33/50
# 188/188 [==============================] - 113s 601ms/step - loss: 1.6479 - sparse_categorical_accuracy: 0.5140 - val_loss: 1.7380 - val_sparse_categorical_accuracy: 0.5165
# Epoch 34/50
# 188/188 [==============================] - 115s 609ms/step - loss: 1.6636 - sparse_categorical_accuracy: 0.4947 - val_loss: 1.7405 - val_sparse_categorical_accuracy: 0.4820
# Epoch 35/50
# 188/188 [==============================] - 115s 609ms/step - loss: 1.5937 - sparse_categorical_accuracy: 0.5208 - val_loss: 1.8249 - val_sparse_categorical_accuracy: 0.4505
# Epoch 36/50
# 188/188 [==============================] - 113s 601ms/step - loss: 1.5830 - sparse_categorical_accuracy: 0.5305 - val_loss: 1.6459 - val_sparse_categorical_accuracy: 0.5015
# Epoch 37/50
# 188/188 [==============================] - 114s 603ms/step - loss: 1.5459 - sparse_categorical_accuracy: 0.5373 - val_loss: 1.6335 - val_sparse_categorical_accuracy: 0.5390
# Epoch 38/50
# 188/188 [==============================] - 117s 622ms/step - loss: 1.5158 - sparse_categorical_accuracy: 0.5472 - val_loss: 1.7850 - val_sparse_categorical_accuracy: 0.4535
# Epoch 39/50
# 188/188 [==============================] - 116s 615ms/step - loss: 1.4766 - sparse_categorical_accuracy: 0.5556 - val_loss: 1.7436 - val_sparse_categorical_accuracy: 0.4970
# Epoch 40/50
# 188/188 [==============================] - 116s 617ms/step - loss: 1.4675 - sparse_categorical_accuracy: 0.5556 - val_loss: 1.6104 - val_sparse_categorical_accuracy: 0.5240
# Epoch 41/50
# 188/188 [==============================] - 117s 621ms/step - loss: 1.4234 - sparse_categorical_accuracy: 0.5662 - val_loss: 1.5295 - val_sparse_categorical_accuracy: 0.5571
# Epoch 42/50
# 188/188 [==============================] - 119s 633ms/step - loss: 1.4436 - sparse_categorical_accuracy: 0.5713 - val_loss: 1.5082 - val_sparse_categorical_accuracy: 0.5556
# Epoch 43/50
# 188/188 [==============================] - 118s 626ms/step - loss: 1.3867 - sparse_categorical_accuracy: 0.5878 - val_loss: 1.4884 - val_sparse_categorical_accuracy: 0.5495
# Epoch 44/50
# 188/188 [==============================] - 116s 615ms/step - loss: 1.3556 - sparse_categorical_accuracy: 0.5915 - val_loss: 1.4669 - val_sparse_categorical_accuracy: 0.5721
# Epoch 45/50
# 188/188 [==============================] - 116s 617ms/step - loss: 1.3352 - sparse_categorical_accuracy: 0.5937 - val_loss: 1.5418 - val_sparse_categorical_accuracy: 0.5315
# Epoch 46/50
# 188/188 [==============================] - 115s 610ms/step - loss: 1.3462 - sparse_categorical_accuracy: 0.5901 - val_loss: 1.5187 - val_sparse_categorical_accuracy: 0.5480
# Epoch 47/50
# 188/188 [==============================] - 116s 615ms/step - loss: 1.2920 - sparse_categorical_accuracy: 0.6090 - val_loss: 1.4402 - val_sparse_categorical_accuracy: 0.5796
# Epoch 48/50
# 188/188 [==============================] - 116s 617ms/step - loss: 1.2668 - sparse_categorical_accuracy: 0.6130 - val_loss: 1.4315 - val_sparse_categorical_accuracy: 0.5736
# Epoch 49/50
# 188/188 [==============================] - 116s 616ms/step - loss: 1.2319 - sparse_categorical_accuracy: 0.6272 - val_loss: 1.4399 - val_sparse_categorical_accuracy: 0.5541
# Epoch 50/50
# 188/188 [==============================] - 114s 607ms/step - loss: 1.2596 - sparse_categorical_accuracy: 0.6195 - val_loss: 1.5966 - val_sparse_categorical_accuracy: 0.5165

# %% [markdown]
# ## **Traing Results**

# %%
acc = history.history['sparse_categorical_accuracy']
val_acc = history.history['val_sparse_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = history.epoch

plt.figure(figsize = (16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label = 'Training Accuracy')
plt.plot(epochs_range, val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label = 'Training Loss')
plt.plot(epochs_range, val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### **Model Evalution**

# %%
test_loss, test_acc = model.evaluate(test_data, verbose = 0)

print(f"Loss on Testing data: {test_loss}")
print(f"Accuracy on Testing data: {test_acc}")
# Out:
# Loss on Testing data: 1.7100931406021118
# Accuracy on Testing data: 0.5074424743652344

# %% [markdown]
# ### **Plotting Test Results**

# %%
plot_generator_images(test_data, "Testing data", labelDecDict, print_pred = True, model = model)

# %% [markdown]
# ## **Saving Model**

# %%
model.save('/content/drive/MyDrive/SigTuple/Models/Oxford-IIIT-Pet_Image_Classifier')
# Out:
# WARNING:absl:Found untraced functions such as leaky_re_lu_layer_call_fn, leaky_re_lu_layer_call_and_return_conditional_losses, leaky_re_lu_1_layer_call_fn, leaky_re_lu_1_layer_call_and_return_conditional_losses, leaky_re_lu_2_layer_call_fn while saving (showing 5 of 35). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/SigTuple/Models/Oxford-IIIT-Pet_Image_Classifier/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/SigTuple/Models/Oxford-IIIT-Pet_Image_Classifier/assets

# %% [markdown]
# # **Load Saved Model**

# %%
saved_model = tf.keras.models.load_model('/content/drive/MyDrive/SigTuple/Models/Oxford-IIIT-Pet_Image_Classifier')

sm_test_loss, sm_test_acc = saved_model.evaluate(test_data, verbose = 0)

print(f"Loss on Testing data: {sm_test_loss}")
print(f"Accuracy on Testing data: {sm_test_acc}")
# Out:
# Loss on Testing data: 1.7100929021835327
# Accuracy on Testing data: 0.5074424743652344

# %% [markdown]
# # **Another way of CNN Model**
